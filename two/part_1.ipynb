# %% [markdown]
# ### Part 1:  Image Homography Estimation

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
## Set image paths here and run the rest of the code to achieve same results

# %%
# Compute Homography using OpenCV

# %%
# Use the homography matrix to warp source image to destination

# %%
#  Visualization

# %%
# manually select 4 corners
# corners are selected in the order left top corner, right top corner, right bottom corner, and left bottom corner
# Out:
# 👉 Click 4 points on the image: Select 4 points
# ✅ Selected points: [[ 300.3658   744.08875]
#  [2759.2402   735.4307 ]
#  [2715.9502  3436.7295 ]
#  [ 369.62988 3402.0974 ]]

# %%
#  manually select 4 corners
# corners are selected in the order left top corner, right top corner, right bottom corner, and left bottom corner
# Out:
# 👉 Click 4 points on the image: Select 4 points
# ✅ Selected points: [[ 438.89395   891.2749  ]
#  [1676.9891     25.474026]
#  [1746.2533   3834.9978  ]
#  [ 525.474    2943.223   ]]

# %%
# manually select 4 corners
# corners are selected in the order left top corner, right top corner, right bottom corner, and left bottom corner
# Out:
# 👉 Click 4 points on the image: Select 4 points
# ✅ Selected points: [[ 915.0844   129.37013]
#  [1651.0151   977.855  ]
#  [1564.435   2778.7207 ]
#  [ 837.16235 3731.1018 ]]

# %%
# visualize results

# %%
# Visualization

# %%
# visualize results

# %% [markdown]
# ### Homography for Scene 2

# %%
# manually select 4 corners
# corners are selected in the order left top corner, right top corner, right bottom corner, and left bottom corner
# Out:
# 👉 Click 4 points on the image: Select 4 points
# ✅ Selected points: [[ 257.07574   94.7381 ]
#  [2759.2402   120.71212]
#  [2638.028   3817.682  ]
#  [ 334.99783 3852.314  ]]

# %%
#  manually select 4 corners
# corners are selected in the order left top corner, right top corner, right bottom corner, and left bottom corner
# Out:
# 👉 Click 4 points on the image: Select 4 points
# ✅ Selected points: [[1062.2705    60.10606]
#  [1780.8853   796.0368 ]
#  [1798.2013  3021.145  ]
#  [1148.8507  3843.6558 ]]

# %%
# Step 4: Visualization

# %%
# visualize results

# %% [markdown]
# ##### Homography is a projective transformation that relates two images of same planar surface under different perspectives. By defining at least four point correspondence between the distorted image and a reference rectangular image, the homography matrix H (a 3x3 transformation matrix) maps each pixel in the Source image to its geometrically correct position.
# ##### Applying the inverse homography warps the distorted image into the rectified coordinate system, this confirms the goal of rectification, which is to remove the effects of perspective distortion so that objects that are planar in the scene appear fronto-parallel in the image.
