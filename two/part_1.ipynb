# %%
# %pip install opencv-python
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install scipy

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
from scipy.ndimage import gaussian_filter, convolve
from math import ceil, sqrt, pi
from skimage import exposure

# %% [markdown]
# ### Part 1: Perspective and orthographic projections

# %% [markdown]
# ##### Q1. Observations: In the perspective projection, the part of the building closer to the camera appears larger than the farther end of the building, where the lines along the walls seems to vanish while getting closer to the end. In the approximate orthographic projection, the size of the walls do not change, the lines drawn seems to be parallel.
