# %% [markdown]
# ### Part 2: Creative Application (Exploration and Extension)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
# Compute Homography using OpenCV

# %%
# Use the homography matrix to warp source image to destination

# %%
# Visualize

# %%
# manually select 4 corners
# corners are selected in the order left top corner, right top corner, right bottom corner, and left bottom corner
# Out:
# 👉 Click 4 points on the image:
# ✅ Selected points: [[  65.300865  160.19264 ]
#  [ 821.6645    367.98486 ]
#  [ 824.43506   838.9805  ]
#  [ 142.87662  1193.6125  ]]

# %%
# visualize results

# %% [markdown]
# ### With my homography codes from part 1, I decided to take a side view photo of this geologic cross-section from the side and created a "Scanned" version of it. No challenges faced while doing this.
